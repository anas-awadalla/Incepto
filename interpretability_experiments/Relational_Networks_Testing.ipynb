# %% [markdown]
# <a href="https://colab.research.google.com/github/anas-awadalla/Incepto/blob/master/interpretability_experiments/Relational_Networks_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kimhc6028/relational-networks.git
# Out:
# Cloning into 'relational-networks'...
# remote: Enumerating objects: 293, done.
# remote: Total 293 (delta 0), reused 0 (delta 0), pack-reused 293
# Receiving objects: 100% (293/293), 57.88 MiB | 31.44 MiB/s, done.
# Resolving deltas: 100% (170/170), done.

# %%
# !pip install numpy==1.18.1
# !pip install opencv-python==4.2.0.32
# !pip install torch==1.4.0
# !pip intall tensorboard==2.2.0
# !pip install tensorboard-plugin-wit==1.6.0.post2

# %%
# !/content/run.sh
# Out:
# directory ./data already exists
# building test datasets...
# building train datasets...
# saving datasets...
# tcmalloc: large alloc 1141907456 bytes == 0xdfe7c000 @  0x7f8fe0a782a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e2192 0x4e23cb 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f8fe0674b97 0x5b26fa
# tcmalloc: large alloc 1712865280 bytes == 0x123f7e000 @  0x7f8fe0a782a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e2192 0x4e23f3 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f8fe0674b97 0x5b26fa
# datasets saved at ./data/sort-of-clevr.pickle
# 2020-09-01 23:08:34.845474: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data...
# processing data...
# directory ./model already exists
# Training RN (binary) model...
# ...
